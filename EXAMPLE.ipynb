# %% [markdown]
# # Functioning example for the ZIPRA library
# This library provides tools to extract and process the .SAFE file containing Sentinel-2 data

# %% [markdown]
# #### 00 - Install required packages in Google Colab and Jupyter Notebook

# %%
# The '-q' flag means "quiet" (less text output)
# !pip install -q pandas shapely requests leafmap rasterio numpy matplotlib geopandas gdal localtileserver

import sys
import os

# Setup ZIPRA Library Path
# This allows Python to "see" the ZIPRA.py file in the current folder
if os.path.exists('./ZIPRA.py'):
    sys.path.insert(0, os.getcwd())
    print("✓ ZIPRA library found and added to path.")
else:
    print("⚠️ ZIPRA.py not found in the current directory. Please upload it.")

# Create Data Directory
os.makedirs("./DATA", exist_ok=True)
print("✓ Data folder ready.")

print("\n🎉 Ready to start! Run the next cells...")
# Out:
# Error processing line 1 of /opt/miniconda3/envs/GPProject/lib/python3.10/site-packages/distutils-precedence.pth:
#
#   Traceback (most recent call last):
#     File "/opt/miniconda3/envs/GPProject/lib/python3.10/site.py", line 195, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named '_distutils_hack'
#
# Remainder of file ignored
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# ✓ ZIPRA library found and added to path.
# ✓ Data folder ready.
#
# 🎉 Ready to start! Run the next cells...

# %% [markdown]
# #### 01 - Import relevant modules

# %%
import pandas as pd
import requests, json, getpass
import leafmap as leafmap
from shapely.geometry import shape
from shapely import geometry

# %% [markdown]
# ## 1. How to get the data

# %% [markdown]
# For using the library, a fundamental step is to download the zip folder containing the data.
# Below, the script guides the user to obtain such data using the Odata endpoint provided by Copernicus Data Space Catalogue in the link [Odata info](https://documentation.dataspace.copernicus.eu/APIs/OData.html)

# %% [markdown]
# ### 1.1 Define the AREA OF INTEREST

# %%
# Draw the AOI on the map below
# Choose a shape, drag the cursor and scroll down
  # Attention: if only a point is chosen, the query will fail
m = leafmap.Map(center=[45.64, 9.60], zoom=5, toolbar_control=False, fullscreen_control=False)
m
# Out:
# Map(center=[45.64, 9.6], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…

# %%
# This section extract the AOI from the map and extracts its bounding box
AOI = m.draw_features
if not AOI:
    print("Please, select an area of interest on the map")
else:
    AOI = shape(AOI[0]['geometry'])
    bbox = AOI.bounds
    print(f"The Shapely geometry: {AOI}")
    print(f"The bounding box in EPSG:4326 is (min_x, min_y, max_x, max_y): {bbox}")
# Out:
# The Shapely geometry: POLYGON ((9.085693 45.5756, 9.085693 45.943511, 9.777832 45.943511, 9.777832 45.5756, 9.085693 45.5756))
# The bounding box in EPSG:4326 is (min_x, min_y, max_x, max_y): (9.085693, 45.5756, 9.777832, 45.943511)

# %% [markdown]
# ### 1.2 Searching Sentinel-2 image products based on the AOI
# This section allows to define some parameters for searching Sentinel-2 products. If the user already has the ID of the product, they can skip this and the following cell

# %%
# Copernicus Data Space Catalogue OData endpoint
catalogue_odata_url = "https://catalogue.dataspace.copernicus.eu/odata/v1"
collection_name = "SENTINEL-2"
product_type = "S2MSI2A"

# USER DEFINED PARAMETERS
# Define the maximum cloud coverage
max_cloud_cover = 30

#Define the period
search_period_start = "2025-09-15T00:00:00.000Z"
search_period_end = "2025-09-30T00:00:00.000Z"
# END OF USER DEFINED PARAMETERS

aoi = geometry.box(*bbox).wkt

# %%
# Copernicus Data Space Catalogue is queried based on AOI, period etc
search_query = f"{catalogue_odata_url}/Products?$filter=Collection/Name eq '{collection_name}' and Attributes/OData.CSC.StringAttribute/any(att:att/Name eq 'productType' and att/OData.CSC.StringAttribute/Value eq '{product_type}') and OData.CSC.Intersects(area=geography'SRID=4326;{aoi}') and ContentDate/Start gt {search_period_start} and ContentDate/Start lt {search_period_end} and Attributes/OData.CSC.DoubleAttribute/any(att:att/Name eq 'cloudCover' and att/OData.CSC.DoubleAttribute/Value le {max_cloud_cover})"
response = requests.get(search_query).json()
result = pd.DataFrame.from_dict(response["value"])
result.head(5)
# Out:
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  ff8596d9-b7d3-46cc-b52d-03bd8e33b396
# 1  application/octet-stream  380ffeb2-643e-4255-a943-49af00e9acef
# 2  application/octet-stream  7057d302-74b8-4774-ab19-023146854a2a
# 3  application/octet-stream  b6283d09-60fd-4907-894e-8012bc15ebad
# 4  application/octet-stream  ddfedcdc-e7cb-4f31-8915-b974a474aa28
#
#                                                 Name  \
# 0  S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_2...
# 1  S2C_MSIL2A_20250915T103041_N0511_R108_T32TMS_2...
# 2  S2B_MSIL2A_20250920T102619_N0511_R108_T32TMR_2...
# 3  S2B_MSIL2A_20250920T102619_N0511_R108_T32TLR_2...
# 4  S2A_MSIL2A_20250917T102711_N0511_R108_T32TLR_2...
#
#                 ContentType  ContentLength                   OriginDate  \
# 0  application/octet-stream      115676135  2025-09-20T14:56:22.000000Z
# 1  application/octet-stream     1163845180  2025-09-15T18:39:23.000000Z
# 2  application/octet-stream      926961590  2025-09-20T15:05:39.000000Z
# 3  application/octet-stream     1250582495  2025-09-20T15:10:15.000000Z
# 4  application/octet-stream     1101566958  2025-09-17T15:36:18.000000Z
#
#                PublicationDate             ModificationDate  Online  \
# 0  2025-09-20T14:59:12.690029Z  2025-09-20T15:05:44.307029Z    True
# 1  2025-09-15T18:47:09.980933Z  2025-09-15T18:58:23.814949Z    True
# 2  2025-09-20T15:09:56.016315Z  2025-09-20T15:11:19.092741Z    True
# 3  2025-09-20T15:14:34.166407Z  2025-09-20T15:14:34.166407Z    True
# 4  2025-09-17T15:45:28.306510Z  2025-09-17T15:45:28.306510Z    True
#
#                   EvictionDate  \
# 0  9999-12-31T23:59:59.999999Z
# 1  9999-12-31T23:59:59.999999Z
# 2  9999-12-31T23:59:59.999999Z
# 3  9999-12-31T23:59:59.999999Z
# 4  9999-12-31T23:59:59.999999Z
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L2A/2025/09/20/S2B_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2025/09/15/S2C_MSIL...
# 2  /eodata/Sentinel-2/MSI/L2A/2025/09/20/S2B_MSIL...
# 3  /eodata/Sentinel-2/MSI/L2A/2025/09/20/S2B_MSIL...
# 4  /eodata/Sentinel-2/MSI/L2A/2025/09/17/S2A_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '915d4fa630130f46e02a22c06ca39891',...
# 1  [{'Value': 'c47dc02f46d8aa411cfbf6ef50d44910',...
# 2  [{'Value': '7910262271923c4a316d0290e3856e5b',...
# 3  [{'Value': '5f21ef743cca275e62c075a84dcd1d6d',...
# 4  [{'Value': 'e22a6ab71c7059b2375f979ec1f8f26b',...
#
#                                          ContentDate  \
# 0  {'Start': '2025-09-20T10:26:19.024000Z', 'End'...
# 1  {'Start': '2025-09-15T10:30:41.025000Z', 'End'...
# 2  {'Start': '2025-09-20T10:26:19.024000Z', 'End'...
# 3  {'Start': '2025-09-20T10:26:19.024000Z', 'End'...
# 4  {'Start': '2025-09-17T10:27:11.024000Z', 'End'...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((9.28446744967108...
# 1  geography'SRID=4326;POLYGON ((9.12748528352368...
# 2  geography'SRID=4326;POLYGON ((8.89970693004134...
# 3  geography'SRID=4326;POLYGON ((6.41593487960282...
# 4  geography'SRID=4326;POLYGON ((7.55805709967543...
#
#                                         GeoFootprint
# 0  {'type': 'Polygon', 'coordinates': [[[9.284467...
# 1  {'type': 'Polygon', 'coordinates': [[[9.127485...
# 2  {'type': 'Polygon', 'coordinates': [[[8.899706...
# 3  {'type': 'Polygon', 'coordinates': [[[6.415934...
# 4  {'type': 'Polygon', 'coordinates': [[[7.558057...

# %% [markdown]
# ### 1.3 Select the image you want to download from the list above: choose the index

# %%
# USER DEFINED PARAMETERS
Index_image = 0  # Change this index to select different images from the search result
path=f"./DATA/"
# END OF USER DEFINED PARAMETERS

# %% [markdown]
# ### 1.4 Set OAuth Client Configuration with Copernicus Dataspace Ecosystem

# %% [markdown]
# Before proceding with the download, the user should create an account on Copernicus Data Space and get OAuth client, a guide can be found at this [link](https://documentation.dataspace.copernicus.eu/APIs/SentinelHub/Overview/Authentication.html)

# %%
# Define variables
Image_Id = result.iloc[Index_image]["Id"]
Image_name = result.iloc[Index_image]["Name"]
PRODUCT_URL = f"https://download.dataspace.copernicus.eu/odata/v1/Products({Image_Id})/$value"
OUTPUT_PATH = path + f"{Image_name}.zip"
# Name of your credentials file with OAuth client id and secret
CREDENTIALS_FILE = "My_credentials.json"

# %%
# Check if the file exists in the current directory
if os.path.exists(CREDENTIALS_FILE):
    print(f"File '{CREDENTIALS_FILE}' found. Loading credentials...")
    try:
        with open(CREDENTIALS_FILE, 'r') as f:
            credentials = json.load(f)
            client_id = credentials.get("username")
            client_secret = credentials.get("password")
        print(" Credentials loaded successfully from file.")
    except Exception as e:
        print(f" Error reading the file: {e}.Please enter your credentials manually.")
        client_id = input("Enter your OAuth client ID: ")
        client_secret = getpass.getpass("Enter your OAuth client secret: ")
else:
    # If file is missing, ask the user
    print(f"File '{CREDENTIALS_FILE}' not found. Please enter your credentials manually.")
    client_id = input("Enter your OAuth client ID for COPERNICUS DATASPACE ECOSYSTEM: ")
    client_secret = getpass.getpass("Enter your OAuth client secret for COPERNICUS DATASPACE ECOSYSTEM: ")      # getpass hides the input for security

print(f"--> Ready to establish a connection to COPERNICUS.")
# Out:
# ⚠️ File 'My_credentials.json' not found. Please enter your credentials manually.
# Enter your OAuth client ID for COPERNICUS DATASPACE ECOSYSTEM: sh-4ed1f4f6-b374-407a-b86d-e8c14e5aea5a
# Enter your OAuth client secret for COPERNICUS DATASPACE ECOSYSTEM: ··········
#  Ready to establish a connection to COPERNICUS with OAuth client: sh-4ed1f4f6-b374-407a-b86d-e8c14e5aea5a

# %% [markdown]
# ### 1.5 Authentication (get token)

# %%
# Get an access token and establish a session
token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
token_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret
}
try:
    # Perform the POST request to get the token
    auth_response = requests.post(token_url, data=token_payload)
    auth_response.raise_for_status() # Stop if credentials are wrong
    # Parse the JSON response
    token_data = auth_response.json()
    access_token = token_data["access_token"]
    expires_in = token_data["expires_in"]
    print(f"SUCCESS: Token response {auth_response.status_code}. Expires in {expires_in} hours.")
except requests.exceptions.RequestException as e:
    print(f" ERROR: Authentication failed {e}")
    print(f"Server Response: {auth_response.text}")
    sys.exit(1) # Stop the script
# Out:
# SUCCESS: Token response 200. Expires in 1800 hours.

# %% [markdown]
# ### 1.6 Download the data

# %%
#Download the image, this might take few minutes
try:
    # Create a session to manage the connection headers
    session = requests.Session()
    session.headers["Authorization"] = f"Bearer {access_token}"
    response = session.get(PRODUCT_URL, stream=True)
    response.raise_for_status()
    zip_data = response.content
    response.close()
    print(f"Starting download from: {PRODUCT_URL}")

    # Writes the downloaded content to a file
    with open(OUTPUT_PATH, 'wb') as f:
        f.write(zip_data)

    print(f"\nData saved to: '{OUTPUT_PATH}' (Size: {len(zip_data)} bytes).")

except requests.exceptions.RequestException as e:
    print(f"\nAn error occurred during the request: {e}")
# Out:
# Starting download from: https://download.dataspace.copernicus.eu/odata/v1/Products(ff8596d9-b7d3-46cc-b52d-03bd8e33b396)/$value
#
# Data saved to: './DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE.zip' (Size: 115676135 bytes).

# %% [markdown]
# # Zipra library example

# %%
from ZIPRA import Band_estraction
path="DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE.zip"
tiff_file, band_list = Band_estraction(path)
# Out:
# File ZIP decompressed successfully.
# band folder: DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA
# Band B02 found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R10m/T32TNR_20250917T102019_B02_10m.jp2
# Band B03 found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R10m/T32TNR_20250917T102019_B03_10m.jp2
# Band B04 found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R10m/T32TNR_20250917T102019_B04_10m.jp2
# Band B08 found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R10m/T32TNR_20250917T102019_B08_10m.jp2
# Band B12 found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R20m/T32TNR_20250917T102019_B12_20m.jp2
# Band SCL found at DATA/S2B_MSIL2A_20250917T102019_N0511_R065_T32TNR_20250917T155807.SAFE/GRANULE/L2A_T32TNR_A044564_20250917T102153/IMG_DATA/R20m/T32TNR_20250917T102019_SCL_20m.jp2
# A total of  6  out of  6  bands have been found.
# File saved as GeoTIFF at DATA/L2A_T32TNR_A044564_20250917T102153.tif with correct metadata.

# %%
from ZIPRA import Band_estraction
tiff_file, band_list = Band_estraction(OUTPUT_PATH)
# Out:
# File ZIP decompressed successfully.
# band folder: ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA
# Band B02 found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R10m/T32TNS_20250920T102619_B02_10m.jp2
# Band B03 found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R10m/T32TNS_20250920T102619_B03_10m.jp2
# Band B04 found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R10m/T32TNS_20250920T102619_B04_10m.jp2
# Band B08 found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R10m/T32TNS_20250920T102619_B08_10m.jp2
# Band B12 found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R20m/T32TNS_20250920T102619_B12_20m.jp2
# Band SCL found at ./DATA/S2B_MSIL2A_20250920T102619_N0511_R108_T32TNS_20250920T142941.SAFE/GRANULE/L2A_T32TNS_A044607_20250920T103302/IMG_DATA/R20m/T32TNS_20250920T102619_SCL_20m.jp2
# A total of  6  out of  6  bands have been found.
# VRT created succesfully
# File resampled and saved as GeoTIFF at ./DATA/L2A_T32TNS_A044607_20250920T103302.tif

# %%
print("Band_list:", band_list)
print("Tiff_file:", tiff_file)
# Out:
# Band_list: ['B02', 'B03', 'B04', 'B08', 'B12', 'SCL']
# Tiff_file: DATA/L2A_T32TNR_A044564_20250917T102153.tif

# %% [markdown]
# ### Area calculations:

# %%
# Do not to consider when running all code above
tiff_file="DATA/L2A_T32TNR_A044564_20250917T102153.tif"
band_list=['B02', 'B03', 'B04', 'B08', 'B12', 'SCL']

# %%
from ZIPRA import Area_calculation
import rasterio

class_list = [1,2,3] #example
SCL_band = band_list.index('SCL') + 1  # Get the band number for SCL
Area_tot, Area_classes = Area_calculation(tiff_file, class_list, SCL_band)
print("Total area of specified classes [m^2]:", Area_tot)
for i, class_value in enumerate(class_list):
    print(f"Area of class {class_value} [m^2]: {Area_classes[i]}")
# Out:
# Total area of specified classes [m^2]: 699478800.0
# Area of class 1 [m^2]: 0.0
# Area of class 2 [m^2]: 45986000.0
# Area of class 3 [m^2]: 653492800.0

# %%
m.set_center(((bbox[0] + bbox[2]) / 2),((bbox[1] + bbox[3]) / 2), zoom=8)
m.add_raster(tiff_file, bands=[band_list.index('B04') + 1, band_list.index('B03') + 1, band_list.index('B02') + 1], layer_name="Sentinel-2 RGB",vmin=0,vmax=3000)
m.add_layer_control()
m
# Out:
# Map(bottom=93882.0, center=[45.5551615, 9.709322499999999], controls=(ZoomControl(options=['position', 'zoom_i…

# %%
# This section extract the AOI clipped from the map and extracts its bounding box
AOI_clipped = m.draw_features[-1] #last drawn feature
if not AOI_clipped:
    print("Please, select an area of interest on the map")
else:
    AOI_clipped = shape(AOI_clipped['geometry'])
    bbox_clipped = AOI_clipped.bounds
    print(f"The Shapely geometry clipped: {AOI_clipped}")
    print(f"The bounding box in EPSG:4326 is (min_x, min_y, max_x, max_y): {bbox_clipped}")
# Out:
# The Shapely geometry clipped: POLYGON ((9.085693 45.5756, 9.085693 45.943511, 9.777832 45.943511, 9.777832 45.5756, 9.085693 45.5756))
# The bounding box in EPSG:4326 is (min_x, min_y, max_x, max_y): (9.085693, 45.5756, 9.777832, 45.943511)

# %%
from ZIPRA import Clip_AOI
AOI_clipped=AOI_clipped.wkt
clipped_tiff = Clip_AOI(tiff_file, AOI_clipped) # mi da errore wkt
print("Clipped raster data path:", clipped_tiff)
# Out:
# Intersection AOI/raster: [ True]
# Clipped raster data path: DATA/L2A_T32TNR_A044564_20250917T102153_CLIPPED.tif

# %%
m.add_raster(clipped_tiff, layer_name="Raster clipped")
m
# Out:
# Map(bottom=23729.0, center=[45.759535, 9.434045], controls=(ZoomControl(options=['position', 'zoom_in_text', '…

# %% [markdown]
# ### EXAMPLE 1: Calculate default Spectral Indices and plot

# %%
# TEST: this code is necessary to reload the library after changes
import importlib
import ZIPRA
importlib.reload(ZIPRA)
from ZIPRA import Indices_calculation

print(" ZIPRA library updated and reloaded successfully!")
# Out:
#  ZIPRA library updated and reloaded successfully!

# %%
# test available bands
with rasterio.open(tiff_file) as src:
    band_desc = src.descriptions  # tuple of band descriptions
    print("Bands available in TIFF:", band_desc)
# Out:
# Bands available in TIFF: ('B02', 'B03', 'B04', 'B08', 'B12', 'SCL')

# %%
tiff_file="DATA/L2A_T32TNR_A044564_20250917T102153.tif"
# Calculate default indices (NDVI, NBR, NDWI)
tiff_with_indices, calculated = Indices_calculation(tiff_file)
print(f"Indices calculated: {calculated}")
print(f"Output file: {tiff_with_indices}")
# Out:
# Calculated NDVI (with masking)
# Calculated NBR (with masking)
# Calculated NDWI (with masking)
# Saved with indices to: DATA/L2A_T32TNR_A044564_20250917T102153_indices.tif
# Indices calculated: ['NDVI', 'NBR', 'NDWI']
# Output file: DATA/L2A_T32TNR_A044564_20250917T102153_indices.tif

# %%
import numpy as np
import matplotlib.pyplot as plt

with rasterio.open(tiff_with_indices) as src:
    # read the bands from file (7=NDVI, 8=NBR, 9=NDWI)
    ndvi = src.read(7)
    nbr = src.read(8)
    ndwi = src.read(9)

    # using np.nanmin instead of .min() to avoid nan
    print(f"NDVI (Band 7): Min={np.nanmin(ndvi):.2f}, Max={np.nanmax(ndvi):.2f}, Mean={np.nanmean(ndvi):.2f}")
    print(f"NBR  (Band 8): Min={np.nanmin(nbr):.2f}, Max={np.nanmax(nbr):.2f}")
    print(f"NDWI (Band 9): Min={np.nanmin(ndwi):.2f}, Max={np.nanmax(ndwi):.2f}")

    # NDVI Visualisation
    plt.figure(figsize=(10,5))
    current_cmap = plt.cm.RdYlGn
    current_cmap.set_bad(color='white')

    plt.imshow(ndvi, cmap=current_cmap, vmin=-1, vmax=1)
    plt.colorbar(label="NDVI")
    plt.title("NDVI")
    plt.show()
# Out:
# NDVI (Band 7): Min=-1.00, Max=0.88, Mean=0.32
# NBR  (Band 8): Min=-1.00, Max=0.78
# NDWI (Band 9): Min=-1.00, Max=1.00

# %%
import matplotlib.pyplot as plt

# NDWI Visualisation
plt.figure(figsize=(10,5))

# Using 'RdBu' (Red to Blue). Min (-1, soil) RED. Max (+1, water) BLUE.
current_cmap = plt.cm.RdBu
current_cmap.set_bad(color='white') # Borders /NoData

plt.imshow(ndwi, cmap=current_cmap, vmin=-1, vmax=1)
plt.colorbar(label="NDWI (Red=Soil, Blue=Water)")
plt.title("NDWI - Normalized Difference Water Index")
plt.show()

# %% [markdown]
# ### EXAMPLE 2: Calculate specific spectral indices

# %%
from ZIPRA import Indices_calculation

#tiff_file="./DATA/L2A_T32VNJ_A053516_20250920T103738.tif"
indices_list= ["EVI","NDBI","NBN"]
# Calculate default indices (NDVI, NBR, NDWI)
tiff_with_indices, calculated = Indices_calculation(tiff_file, indices_list)
print(f"Indices calculated: {calculated}")
print(f"Output file: {tiff_with_indices}")
# Out:
# Warning: The following indices are not supported and will be skipped: NBN
# Calculated EVI (with masking)
# Skipping NDBI: Missing bands ['B11']
# Saved with indices to: DATA/L2A_T32TNR_A044564_20250917T102153_indices.tif
# Indices calculated: ['EVI']
# Output file: DATA/L2A_T32TNR_A044564_20250917T102153_indices.tif
